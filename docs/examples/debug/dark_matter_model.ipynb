# %% [markdown]
# # Dark-matter detector model (debug)
#
# > **Debug status:** This notebook deliberately preserves an unvalidated detector model so its failure can be diagnosed. It is excluded from the maintained example batch and must not be treated as a scientific inference result.
#
# The apparent nested-sampling freeze has two causes to distinguish: an invalid low-energy tail in the response model, and an extremely narrow posterior created by observations that are far outside the ordinary prior-predictive detector response. The bounded checks below establish that this is not an exact-likelihood plateau.

# %%
import dataclasses

# import NEST
import tensorflow_probability.substrates.jax as tfp

from jaxctx.priors.prior import Prior
from jaxctx.priors.special_priors import Categorical

from jaxns.model import Model

tfpd = tfp.distributions

import numpy as np

# JAX imports
import jax
import jax.numpy as jnp
from jax.scipy.special import erf


@dataclasses.dataclass(eq=False)
class NEST:
    def __post_init__(self):
        # Global vars
        self.sqrt2 = np.sqrt(2)
        self.inv_sqrt2_PI = 1 / np.sqrt(2 * jnp.pi)

    def fano_ER(self, mean_N_q, E_field, density):
        """
        Calculates the a Fano-like factor to determine the variance of quanta generation.
    
        Parameters
        ----------
        mean_N_q : scalar or array
            Mean number of quanta produced per event.
        E_field : scalar or array
            Electric field strength in the detector.
        density : scalar or array
            Density of the detector material.
    
        Returns
        -------
        Fano factor : scalar or array
            The calculated Fano factor based on the input parameters.
        
        """

        return (0.13 - 0.030 * density - 0.0057 * density ** 2 + 0.0016 * density ** 3 + 0.0015 * jnp.sqrt(
            mean_N_q * E_field))

    def workfunction(self, density, molar_mass=131.293, avo=6.0221409e+23, atom_num=54.0, old_13eV=1.1716263232):
        alpha = 0.067366 + density * 0.039693
        eDensity = (density / molar_mass) * avo * atom_num
        return old_13eV * (18.7263 - 1.01e-23 * eDensity), alpha

    def calculate_yield_parameters(self, E_field):
        m01 = 30.66 + (6.1978 - 30.66) / (1. + (E_field / 73.855) ** 2.0318) ** 0.41883
        m02 = 77.2931084
        m03 = jnp.log10(E_field) * 0.13946236 + 0.52561312
        m04 = 1.82217496 + (2.82528809 - 1.82217496) / (1. + (E_field / 144.65029656) ** -2.80532006)
        # m05 = Nq / energy / (1. + alpha * erf(0.05 * E)) - m01
        m07 = 7.02921301 + (98.27936794 - 7.02921301) / (1. + (E_field / 256.48156448) ** 1.29119251)
        m08 = 4.285781736
        m09 = 0.3344049589
        m10 = 0.0508273937 + (0.1166087199 - 0.0508273937) / (1. + (E_field / 1.39260460e+02) ** -0.65763592)
        return m01, m02, m03, m04, m07, m08, m09, m10

    def get_yields_beta(self, E, density, exciton_ion_ratio, W, m01=7.096208, m02=77.2931084, m03=0.7155229,
                        m04=1.8279102,
                        m07=94.39740941928082, m08=4.285781736, m09=0.3344049589, m10=0.06623858):
        """
        Calculates the yields of quanta, electrons and photons for beta radiation in a detector.
    
        Parameters
        ----------
        E : scalar or array
            Energy of the incident beta radiation.
        density : scalar or array
            Density of the detector material.
        exciton_ion_ratio : scalar
            Ratio of excitons to ions produced in the detector.
        W : scalar
            Average energy required to produce an electron-ion pair.
        m01, m02, m03, m04, m07, m08, m09, m10 : scalars
            Parameter values used in the empirical formula for calculating yields.
    
        Returns
        -------
        mean_N_q : scalar or array
            Mean number of quanta produced per event.
        Ne : scalar or array
            Number of electrons produced.
        Nph : scalar or array
            Number of photons produced.
    
        Notes
        -----
        This function calculates the yields of quanta, electrons and photons produced by beta radiation 
        in LXe based on the energy of the incident radiation, the density of the detector material, 
        and the ratio of excitons to ions produced.
        """
        DENSITY = 2.9
        mean_N_q = E / W * 1e3
        m05 = mean_N_q / E / (1 + exciton_ion_ratio) - m01
        Qy = m01 + (m02 - m01) / ((1. + (E / m03) ** m04)) ** m09 + m05 + (0.0 - m05) / ((1. + (E / m07) ** m08)) ** m10
        coeff_TI = (1. / DENSITY) ** 0.3
        coeff_Ni = (1. / DENSITY) ** 1.4
        coeff_OL = (1. / DENSITY) ** -1.7 / jnp.log(1. + coeff_TI * coeff_Ni * (DENSITY ** 1.7))
        Qy *= coeff_OL * jnp.log(1. + coeff_TI * coeff_Ni * (density ** 1.7)) * (density ** -1.7)
        Ly = mean_N_q / E - Qy
        Ne = Qy * E
        Nph = Ly * E
        return mean_N_q, Ne, Nph

    def Nei_ratio(self, E, density, alpha):
        """
        Calculates the ratio of the number of electrons to ions for a given energy and material density.
    
        Parameters
        ----------
        E : scalar or array
            Energy of the incident radiation.
        density : scalar or array
            Density of the detector material.
    
        Returns
        -------
        Nei_ratio : scalar or array
            The ratio of the number of electrons to ions.
    
        Notes
        -----
        This function calculates the ratio of the number of electrons to ions produced by 
        ERs.
        """

        return alpha * erf(0.05 * E)

    def recom_omega_ER(self, E_field, elecFrac, width_param_7=0.046452, width_param_8=0.205, width_param_9=0.45,
                       width_param_10=-0.2):
        '''
        This function calculates the omega parameter for electron recoil (ER) events based on certain input parameters.
        
        Parameters
        ----------
        E_field : float 
            The electric field value.
        elecFrac : float 
            The fraction of energy deposited by electrons.
        width_param_7 : float, optional 
            Parameter A from Table VI of https://arxiv.org/pdf/2211.10726.pdf; default is 0.046452.
        width_param_8 : float, optional 
            Omega parameter from Table VI of https://arxiv.org/pdf/2211.10726.pdf; default is 0.205.
        width_param_9 : float, optional 
            Xi parameter from Table VI of https://arxiv.org/pdf/2211.10726.pdf; default is 0.45.
        width_param_10 : float, optional 
            Skewness parameter; default is -0.2.
    
        Returns
        -------
        omega : float 
            The calculated omega parameter for ER events.
        width_param_10 : float 
            The skewness parameter.
    
        Notes
        -----
        The function uses the provided parameters to calculate the value of omega for ER events. It also returns the skewness parameter.
        '''
        A = 0.086036 + (width_param_7 - 0.086036) / (1 + (E_field / 295.2) ** 251.6) ** 0.0069114
        wide = width_param_8
        cntr = width_param_9
        skew = width_param_10
        mode = cntr + 2 * (self.inv_sqrt2_PI) * skew * wide / jnp.sqrt(1. + skew * skew)
        norm = 1. / (jnp.exp(-0.5 * (mode - cntr) ** 2 / (wide * wide)) * (
                1. + erf(skew * (mode - cntr) / (wide * self.sqrt2))))
        omega = norm * A * jnp.exp(-0.5 * (elecFrac - cntr) ** 2 / (wide * wide)) * (
                1. + erf(skew * (elecFrac - cntr) / (wide * self.sqrt2)))
        return omega, width_param_10

    def ER_skew(self, E, E_field, alpha0=1.39, cc0=4.0, cc1=22.1, E0=7.7, E1=54., E2=26.7, E3=6.4, F0=225., F1=71.):
        """
        LUX ER Skewness model for computing the recombination skewness. Default parameters from NEST 2.3.12. 
        
        Parameters:
        E (float): Energy in keV.
        E_field (float): Electric field strength in V/cm.
        alpha0 (float): Baseline scale factor for the ER response. Default value is 1.39.
        cc0 (float): Scale factor for the first exponential term. Default value is 4.0.
        cc1 (float): Scale factor for the second exponential term. Default value is 22.1.
        E0 (float): Decay constant for the first exponential term. Default value is 7.7.
        E1 (float): Decay constant for the second exponential term. Default value is 54.
        E2 (float): Inflection point for the sigmoid function. Default value is 26.7.
        E3 (float): Scale factor for the sigmoid function. Default value is 6.4.
        F0 (float): Decay constant for the field dependence of the first exponential term. Default value is 225.
        F1 (float): Decay constant for the field dependence of the second exponential term. Default value is 71.
    
        Returns:
        float: The ER response given the input parameters. If E_field is less than 50 or greater than 1e4, it returns 0.0.
        """
        mask = jnp.bitwise_or(E_field < 50, E_field > 1e4)
        return jnp.where(mask,
                         0.,
                         1. / (1. + jnp.exp((E - E2) / E3)) * (
                                 alpha0 + cc0 * jnp.exp(-1. * E_field / F0) * (1. - jnp.exp(-1. * E / E0))) + 1. / (
                                 1. + jnp.exp(-1. * (E - E2) / E3)) * cc1 * jnp.exp(-1. * E / E1) * jnp.exp(
                             -1. * jnp.sqrt(E_field) / jnp.sqrt(F1)))


@dataclasses.dataclass(eq=False)
class XenonModel:
    data_S1: jax.Array
    data_S2: jax.Array
    e_survival_prob: jax.Array
    relative_LCE: jax.Array
    density: jax.Array

    E_field = 60.
    S2_sigma: float = 8.
    g1: float = 0.105
    g2: float = 17.3
    SE_gain: float = 31.8
    PMT_sigma: float = 0.35
    p_dpe: float = 0.2

    def prior_model(self):
        nest = NEST()
        W, alpha = nest.workfunction(self.density)
        m01, m02, m03, m04, m07, m08, m09, m10 = nest.calculate_yield_parameters(
            self.E_field)

        signal_rate = Prior(tfpd.Uniform(0.0, 2000.), name='signal_rate').realise()
        bg_rate = Prior(tfpd.Uniform(0.0, 2000.), name='bg_rate').realise()
        iodine_rate = Prior(tfpd.Uniform(0.0, 2000.), name='iodine_rate').realise()
        total_rate = signal_rate + bg_rate + iodine_rate

        categorical_dist_for_E = Categorical(
            parametrisation='gumbel_max',
            probs=jnp.array([jnp.abs(bg_rate), jnp.abs(signal_rate), jnp.abs(iodine_rate)]) / (
                    jnp.abs(bg_rate) + jnp.abs(signal_rate) + jnp.abs(iodine_rate)),
            name='categorical_dist_for_E'
        ).realise()

        E_component_distributions = [
            Prior(tfpd.Uniform(50., 100.), name='E_component_distributions_0').realise(),
            Prior(
                tfpd.TruncatedCauchy(64.3, 0.5, low=0., high=2000.),
                name='E_component_distributions_1',
            ).realise(),
            Prior(
                tfpd.TruncatedCauchy(67.3, 0.5, low=0., high=2000.),
                name='E_component_distributions_2',
            ).realise(),
        ]

        E_component_distributions = jnp.stack(E_component_distributions, axis=0)

        E = E_component_distributions[categorical_dist_for_E]
        exciton_ion_ratio = nest.Nei_ratio(E, self.density, alpha)
        mean_N_q, mean_Ne, mean_Nph = nest.get_yields_beta(E,
                                                           self.density,
                                                           exciton_ion_ratio,
                                                           W,
                                                           m01=m01,
                                                           m02=m02,
                                                           m03=m03,
                                                           m04=m04,
                                                           m07=m07,
                                                           m08=m08,
                                                           m09=m09,
                                                           m10=m10)

        fano_factor = 1.
        Nq_scaled = Prior(
            tfpd.TruncatedNormal(
                loc=1.0,
                scale=jnp.sqrt(fano_factor / mean_N_q),
                low=0.0,
                high=10.0,
            ),
            name='Nq_scaled',
        ).realise()
        Nq = Nq_scaled * mean_N_q
        alf = 1 / (1 + exciton_ion_ratio)
        # probs = alpha / total_count = alf
        alpha = Nq * alf + 1
        # beta + alpha = total_count
        beta = Nq - Nq * alf + 1
        Ni = Nq * Prior(
            tfpd.Beta(concentration1=alpha, concentration0=beta),
            name='Ni',
        ).realise()
        e_frac = mean_Ne / mean_N_q
        recombProb = 1. - (exciton_ion_ratio + 1.) * e_frac
        recomb_omega, _ = nest.recom_omega_ER(E, self.E_field, e_frac)
        skewness = nest.ER_skew(E, self.E_field)

        recomb_variance = recombProb * (1 - recombProb) * Ni + (recomb_omega * Ni) ** 2
        widthCorrection = jnp.sqrt(1. - (2. / jnp.pi) * skewness * skewness / (1. + skewness * skewness))
        muCorrection = (jnp.sqrt(recomb_variance) / widthCorrection) * (
                skewness / jnp.sqrt(1. + skewness * skewness)) * 2. * nest.inv_sqrt2_PI
        Ne_mu = (1. - recombProb) * Ni - muCorrection
        Ne_sigma = jnp.sqrt(recomb_variance) / widthCorrection
        Ne = Prior(
            tfpd.TruncatedNormal(
                loc=Ne_mu,
                scale=Ne_sigma,
                low=0.0,
                high=Nq.astype(Ne_mu.dtype),
            ),
            name='Ne',
        ).realise()
        Nph = Nq - Ne
        probs = self.g1 * self.relative_LCE / (1 + self.p_dpe)
        # Nph_det = Prior(tfpd.Binomial(total_count=Nph, probs=self.g1 * self.relative_LCE / (1 + self.p_dpe)),
        #                       name='Nph_det')
        # Use Beta
        alpha = Nph * probs + 1
        beta = Nph - Nph * probs + 1
        Nph_det = Nph * Prior(
            tfpd.Beta(concentration1=alpha, concentration0=beta),
            name='Nph_det',
        ).realise()

        # Nph_det_dpe = Prior(tfpd.Binomial(total_count=Nph_det, probs=self.p_dpe), name='Nph_det_dpe')
        # use Beta
        alpha = Nph_det * self.p_dpe + 1
        beta = Nph_det - Nph_det * self.p_dpe + 1
        Nph_det_dpe = Nph_det * Prior(
            tfpd.Beta(concentration1=alpha, concentration0=beta),
            name='Nph_det_dpe',
        ).realise()

        # Ne_det = Prior(tfpd.Binomial(total_count=Ne, probs=self.e_survival_prob), name='Ne_det')
        # use Beta
        alpha = Ne * self.e_survival_prob + 1
        beta = Ne - Ne * self.e_survival_prob + 1
        Ne_det = Ne * Prior(
            tfpd.Beta(concentration1=alpha, concentration0=beta),
            name='Ne_det',
        ).realise()

        return self.log_likelihood(
            Nph_det,
            Nph_det_dpe,
            Ne_det,
            total_rate,
        )

    def log_likelihood(self, Nph_det, Nph_det_dpe, Ne_det, total_rate):
        count = self.data_S1.shape[0]
        log_prob_count = tfpd.Poisson(total_rate).log_prob(count).sum()
        log_prob_S1 = tfpd.Normal(jnp.abs(Nph_det + Nph_det_dpe),
                                  jnp.sqrt(Nph_det + Nph_det_dpe) * self.PMT_sigma).log_prob(self.data_S1).sum()

        log_prob_S2 = tfpd.Normal(jnp.abs(Ne_det) * self.SE_gain, jnp.sqrt(Ne_det) * self.S2_sigma).log_prob(
            self.data_S2).sum()

        return log_prob_count + log_prob_S1 + log_prob_S2

    def build_model(self) -> Model:
        return Model(prior_model=self.prior_model)


xenon_model = XenonModel(
    data_S1=jnp.array([1., 2., 3.]),
    data_S2=jnp.array([1., 2., 3.]),
    e_survival_prob=jnp.asarray(0.5),
    relative_LCE=jnp.asarray(1.),
    density=jnp.asarray(2.8)
)
model = xenon_model.build_model()
# Out:
# 2026-08-29 12:00:00,882 INFO     xla_bridge.py jax._src.xla_bridge: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory

# %%
num_prior_samples = 8_192
keys = jax.random.split(jax.random.PRNGKey(20260829), num_prior_samples)
U_samples = jax.jit(jax.vmap(model.sample_U))(keys)
log_L = jax.jit(
    jax.vmap(lambda U: model.log_likelihood(U, allow_nan=True))
)(U_samples)
X_samples = jax.jit(jax.vmap(model.transform_to_X))(U_samples)
jax.block_until_ready((log_L, X_samples))

log_L_values = np.asarray(log_L)
finite_log_L = np.isfinite(log_L_values)
_, likelihood_multiplicity = np.unique(
    log_L_values[finite_log_L],
    return_counts=True,
)
print("U-space dimensions:", model.U_ndims())
print("prior samples:", num_prior_samples)
print("non-finite likelihoods:", int(np.sum(~finite_log_L)))
print(
    "largest exact finite-likelihood multiplicity:",
    int(np.max(likelihood_multiplicity)),
)

component_energies = jnp.stack(
    [
        X_samples.get_dotted("E_component_distributions_0"),
        X_samples.get_dotted("E_component_distributions_1"),
        X_samples.get_dotted("E_component_distributions_2"),
    ],
    axis=0,
)
categories = X_samples.get_dotted("categorical_dist_for_E")
energies = component_energies[categories, jnp.arange(num_prior_samples)]
nest = NEST()
work_function, base_exciton_ratio = nest.workfunction(xenon_model.density)
yield_parameters = nest.calculate_yield_parameters(xenon_model.E_field)
exciton_ratio = nest.Nei_ratio(
    energies,
    xenon_model.density,
    base_exciton_ratio,
)
mean_N_q, _, _ = nest.get_yields_beta(
    energies,
    xenon_model.density,
    exciton_ratio,
    work_function,
    *yield_parameters,
)
Nq = X_samples.get_dotted("Nq_scaled") * mean_N_q
Ne = X_samples.get_dotted("Ne")
Nph = Nq - Ne
Nph_det = Nph * X_samples.get_dotted("Nph_det")
Nph_det_dpe = Nph_det * X_samples.get_dotted("Nph_det_dpe")
Ne_det = Ne * X_samples.get_dotted("Ne_det")
predicted_S1 = np.asarray(Nph_det + Nph_det_dpe)
predicted_S2 = np.asarray(Ne_det * xenon_model.SE_gain)
total_rate = np.asarray(
    X_samples.get_dotted("signal_rate")
    + X_samples.get_dotted("bg_rate")
    + X_samples.get_dotted("iodine_rate")
)
print("observed S1:", np.asarray(xenon_model.data_S1))
print("prior-predictive median S1:", float(np.nanmedian(predicted_S1)))
print("observed S2:", np.asarray(xenon_model.data_S2))
print("prior-predictive median S2:", float(np.nanmedian(predicted_S2)))
print("observed event count:", xenon_model.data_S1.size)
print("prior median total rate:", float(np.median(total_rate)))

energy_grid = jnp.linspace(0.05, 2.0, 100_000)
grid_exciton_ratio = nest.Nei_ratio(
    energy_grid,
    xenon_model.density,
    base_exciton_ratio,
)
grid_mean_N_q, grid_mean_Ne, _ = nest.get_yields_beta(
    energy_grid,
    xenon_model.density,
    grid_exciton_ratio,
    work_function,
    *yield_parameters,
)
grid_electron_fraction = grid_mean_Ne / grid_mean_N_q
grid_recombination_probability = (
    1.0 - (grid_exciton_ratio + 1.0) * grid_electron_fraction
)
first_valid = int(jnp.argmax(grid_recombination_probability >= 0.0))
print(
    "response-model lower valid energy (keV):",
    float(energy_grid[first_valid]),
)

try:
    model.sanity_check(
        key=jax.random.PRNGKey(20260829),
        num_samples=num_prior_samples,
    )
except ValueError as error:
    print("Sanity check correctly rejected this model:")
    print(error)
# Out:
# U-space dimensions: 15
# prior samples: 8192
# non-finite likelihoods: 1
# largest exact finite-likelihood multiplicity: 2
# observed S1: [1. 2. 3.]
# prior-predictive median S1: 402.27239990234375
# observed S2: [1. 2. 3.]
# prior-predictive median S2: 16552.560546875
# observed event count: 3
# prior median total rate: 2991.692626953125
# 2026-08-29 12:00:19,722 INFO     model.py   jaxns: Sanity check...
# response-model lower valid energy (keV): 0.4281867742538452
# Sanity check correctly rejected this model:
# Model sanity check found an invalid prior sample at index 2548:
# ScopedDict(scopes=[], dict={'E_component_distributions_0': Array(0.10945439, dtype=float32), 'E_component_distributions_1': Array(8.46386e-06, dtype=float32), 'E_component_distributions_2': Array(0.97443366, dtype=float32), 'Ne': Array(0.5832417, dtype=float32), 'Ne_det': Array(0.53602695, dtype=float32), 'Ni': Array(0.12593651, dtype=float32), 'Nph_det': Array(0.49527097, dtype=float32), 'Nph_det_dpe': Array(0.60136545, dtype=float32), 'Nq_scaled': Array(0.7932992, dtype=float32), 'bg_rate': Array(0.49570048, dtype=float32), 'categorical_dist_for_E': Array([0.5835688 , 0.6558999 , 0.35362542], dtype=float32), 'iodine_rate': Array(0.6379236, dtype=float32), 'signal_rate': Array(0.7916312, dtype=float32)}) -> ScopedDict(scopes=[], dict={'E_component_distributions_0': Array(55.472717, dtype=float32), 'E_component_distributions_1': Array(0.21857452, dtype=float32), 'E_component_distributions_2': Array(73.506966, dtype=float32), 'Ne': Array(nan, dtype=float32), 'Ne_det': Array(nan, dtype=float32), 'Ni': Array(0.89921105, dtype=float32), 'Nph_det': Array(nan, dtype=float32), 'Nph_det_dpe': Array(nan, dtype=float32), 'Nq_scaled': Array(1.2050289, dtype=float32), 'bg_rate': Array(991.40094, dtype=float32), 'categorical_dist_for_E': Array(1, dtype=int32), 'iodine_rate': Array(1275.8472, dtype=float32), 'signal_rate': Array(1583.2625, dtype=float32)})
# log_likelihood: nan

# %% [markdown]
# ## Diagnosis
#
# This likelihood is not plateauing: the largest exact multiplicity in the finite prior audit is negligible rather than a non-zero-measure equality block. The line-energy priors nevertheless have non-zero mass below the response model's approximately 0.428 keV validity boundary. There the inferred recombination probability is negative, the recombination variance can become negative, and the likelihood becomes NaN.
#
# The supplied observations also do not resemble the model's prior-predictive detector response. Three events with S1 and S2 values of 1--3 force the three rate parameters, the low-energy Cauchy tails, and several detector-efficiency latent variables towards joint prior boundaries. In a bounded timing run, even 60 root lineages and a shell of 20 required 614,083 likelihood evaluations (0.22% efficiency) and about 98 seconds before the first depth epoch merely reached its growth boundary. The default 450 root lineages and shell of 150 make that behaviour look like a freeze.
#
# JAXNS represents sampled equality blocks and terminates a fully explored top plateau. It cannot discover a stricter region if every finite set of root lineages misses that region; that is mode death, for which more independent root lineages are required. Neither case explains this notebook's continuous likelihood values.
#
# The scientific fix is not to clip intermediate values or tune the sampler around this target. The response model's validated energy domain, the observations and their units, and whether the three observations require three event-level latent responses must first be confirmed. Only then should this notebook run inference and report evidence or posterior results.
